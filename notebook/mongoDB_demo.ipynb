# %%
print('ok')
# Out:
# ok

# %%
''' Connection string for MongoDB connection

mongodb+srv://saurabhkamal1:saurabhkamal1@cluster0.wdaya.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''

# %%
import pandas as pd

# %%
df = pd.read_csv('merged_df.csv')
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom       22.00
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
#
#    Hour  ... frequency recency      T  monetary_value  probability_alive  \
# ...

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 361877     581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 361878     581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 361879     581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 361880     581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 361881     581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...
